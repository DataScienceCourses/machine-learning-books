# %%
import pandas as pd
import numpy as np




country_df = pd.read_csv('../Datasets/world-development/Country.csv')
indicators_df = pd.read_csv('../Datasets/world-development/Indicators.csv')

# %%
country_df.columns
# Out:
# Index([u'CountryCode', u'ShortName', u'TableName', u'LongName', u'Alpha2Code',
#        u'CurrencyUnit', u'SpecialNotes', u'Region', u'IncomeGroup', u'Wb2Code',
#        u'NationalAccountsBaseYear', u'NationalAccountsReferenceYear',
#        u'SnaPriceValuation', u'LendingCategory', u'OtherGroups',
#        u'SystemOfNationalAccounts', u'AlternativeConversionFactor',
#        u'PppSurveyYear', u'BalanceOfPaymentsManualInUse',
#        u'ExternalDebtReportingStatus', u'SystemOfTrade',
#        u'GovernmentAccountingConcept', u'ImfDataDisseminationStandard',
#        u'LatestPopulationCensus', u'LatestHouseholdSurvey',
#        u'SourceOfMostRecentIncomeAndExpenditureData',
#        u'VitalRegistrationComplete', u'LatestAgriculturalCensus',
#        u'LatestIndustrialData', u'LatestTradeData',
#        u'LatestWaterWithdrawalData'],
#       dtype='object')

# %%
indicators_df.columns
# Out:
# Index([u'CountryName', u'CountryCode', u'IndicatorName', u'IndicatorCode',
#        u'Year', u'Value'],
#       dtype='object')

# %%
country_df.head(5)
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
indicators_df.head(5)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
pd.isnull(country_df).count()
# Out:
# CountryCode                                   247
# ShortName                                     247
# TableName                                     247
# LongName                                      247
# Alpha2Code                                    247
# CurrencyUnit                                  247
# SpecialNotes                                  247
# Region                                        247
# IncomeGroup                                   247
# Wb2Code                                       247
# NationalAccountsBaseYear                      247
# NationalAccountsReferenceYear                 247
# SnaPriceValuation                             247
# LendingCategory                               247
# OtherGroups                                   247
# SystemOfNationalAccounts                      247
# AlternativeConversionFactor                   247
# PppSurveyYear                                 247
# BalanceOfPaymentsManualInUse                  247
# ...

# %%
country_df[pd.isnull(country_df)].head(5)
# Out:
#   CountryCode ShortName TableName LongName Alpha2Code CurrencyUnit  \
# 0         NaN       NaN       NaN      NaN        NaN          NaN
# 1         NaN       NaN       NaN      NaN        NaN          NaN
# 2         NaN       NaN       NaN      NaN        NaN          NaN
# 3         NaN       NaN       NaN      NaN        NaN          NaN
# 4         NaN       NaN       NaN      NaN        NaN          NaN
#
#   SpecialNotes Region IncomeGroup Wb2Code            ...             \
# 0          NaN    NaN         NaN     NaN            ...
# 1          NaN    NaN         NaN     NaN            ...
# 2          NaN    NaN         NaN     NaN            ...
# 3          NaN    NaN         NaN     NaN            ...
# 4          NaN    NaN         NaN     NaN            ...
#
#   GovernmentAccountingConcept ImfDataDisseminationStandard  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# ...

# %%
country = country_df.dropna(axis=1)
pd.isnull(country).count()
# Out:
# CountryCode    247
# ShortName      247
# TableName      247
# LongName       247
# dtype: int64

# %%
country.shape
# Out:
# (247, 4)
